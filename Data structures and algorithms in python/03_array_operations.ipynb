# %% [markdown]
# # sortedssignment 3
#
# These sortedssignments sortedre related to different **array operations** like _comparison_ and _sorting_.
# * Read the related course material before doing the assignments from the [Array sorting](https://ttc1050.pages.labranet.jamk.fi/ds_alg_material/materials/03_array_sorting/).
#
# General notes of assignments:
# * NOTE! In general, after the implementation of the function, all assignments have a test program for the function.
# * NOTE! Add your code in the assignments only after the TODO lines.

# %% [markdown]
# ## Assignment 3.1 (1 p)
#
# Create an algorithm, that compares the content of two arrays and
# returns all indexes where elements are different in these arrays.
#
# You should use the following string format (see also `correct_answer_03_01`):
#
#   ``index i: first[i] != second[i]``
#
# Put all the differences you find into a list variable `comp_result` and compare it to the correct answer `correct_answer_03_01`.
#
# Note! The test program has already been implemented, so please don't edit it.

# %%
correct_answer_03_01 = ['index 0: a != e', 'index 3: d != g', 'index 4: e != a', 'index 6: g != d']

first = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
second = ['e', 'b', 'c', 'g', 'a', 'f', 'd', 'h']

def compare(a, b):
    differencies = []  # will include all indexes where elements are different.
    # TODO: Implement comparison between the content of two arrays in each index
    for i, j in zip (range(len(a)), range(len(b))):
        if a[i] != b[j]:
            differencies.append(f"index {i}: {first[i]} != {second[j]}")

                     
    # TODO: Return all indexes where elements are different in these arrays using given string format.
    return differencies

# Test
comp_result = compare(first, second)

assert len(comp_result) == 4, "Error in length"
assert comp_result == correct_answer_03_01
print(f"answer {comp_result} was OK!")
# Out:
# answer ['index 0: a != e', 'index 3: d != g', 'index 4: e != a', 'index 6: g != d'] was OK!

# %% [markdown]
# ## Assignment 3.2 (1 p)
#
# Create own implementation of bubble sort algorithm.
#
# The `letters` list is defined at the beginning of the assignment contains letters. Please don't modify it.
#
# Sort `letters` list using `bubble_sort()` function, the algorithm of which is given as ready-made pseudocode in the assignment's comments.
# * Note! To clarify the Python implementation difference from the pseudocode, it's important not to sort the original list provided as an argument but rather create a new list within the `bubble_sort()` function.
#
# Note! The test program has already been implemented, so please don't edit it.

# %%
correct_answer_03_02 = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l']

letters = ['i', 'j', 'b','h','l','a','k','c','g','f','e','d']

# procedure bubbleSort(A : list of sortable items)
#     n := length(A)
#     repeat
#         swapped := false
#         for i := 1 to n-1 inclusive do
#             { if this pair is out of order }
#             if A[i-1] > A[i] then
#                 { swap them and remember something changed }
#                 swap(A[i-1], A[i])
#                 swapped := true
#             end if
#         end for
#     until not swapped
# end procedure

def bubble_sort(a):
    sorted = []
    for k in range(len(a)):
        sorted.append(a[k])
    # TODO: Sort list and return sorted list with your own implementation of bubble sort.
    for i in range(len(sorted) - 1):
        for j in range (len(sorted) - 1 - i):
            if sorted[j] > sorted[j + 1]:
                temp = sorted[j]
                sorted[j] = sorted[j + 1]
                sorted[j + 1] = temp


                
    return sorted



# Test
sorted_letters = bubble_sort(letters)
print(letters)
assert letters != sorted_letters
assert sorted_letters == correct_answer_03_02
print(f"answer {sorted_letters} was OK!")
# Out:
# ['i', 'j', 'b', 'h', 'l', 'a', 'k', 'c', 'g', 'f', 'e', 'd']
# answer ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l'] was OK!

# %% [markdown]
# ## Assignment 3.3 (1 p)
#
# Create an algorithm that performs the following operations in order:
# 1. Prompt the user for the array size.
# 2. Accept user input for values (as `str`) until the array is filled, and populate the array with non-empty elements.
# 3. Sort the array in ascending order using the `bubble_sort()` function developed in **assignment 3.2**.
#
# Note! The test program has already been implemented, so please don't edit it.

# %%
import unittest

def ask_array_from_user():
    # TODO: Prompt the user for the array size.
    arrsize = int(input(print("What is the array size?")))
    created_array = []
    # TODO: Accept user input for values (as `str`) until the array is filled, and populate the array with non-empty elements.
    iter = 1
    while iter <= arrsize:
        iterelement = str(input(print(f"Give array element {iter}/{arrsize}:")))
        if iterelement != '':
            iter = iter + 1
            created_array.append(iterelement)
            print(f"Element {iterelement} added")
        else:
            print("Try inserting a value to the element next time!")

    # return created_array
    return created_array

def bubble_sort(a):
    sorted = []
    for k in range(len(a)):
        sorted.append(a[k])
    # TODO: Sort list and return sorted list with your own implementation of bubble sort.
    for i in range(len(sorted) - 1):
        for j in range (len(sorted) - 1 - i):
            if sorted[j] > sorted[j + 1]:
                temp = sorted[j]
                sorted[j] = sorted[j + 1]
                sorted[j + 1] = temp


                
    return sorted

# test
list_from_user = ask_array_from_user()
# TODO: Sort the array in ascending order using the bubble_sort function developed in assignment 3.2.
list_sorted = bubble_sort(list_from_user)
sorted_arr = sorted(list_from_user)

unittest.TestCase().assertListEqual(list_sorted, sorted_arr)
print(f"answer {list_sorted} was OK!")
# Out:
# What is the array size?
# Give array element 1/5:
# Try inserting a value to the element next time!
# Give array element 1/5:
# Try inserting a value to the element next time!
# Give array element 1/5:
# Element x added
# Give array element 2/5:
# Element y added
# Give array element 3/5:
# Element b added
# Give array element 4/5:
# Element 1 added
# Give array element 5/5:
# Element a added
# answer ['1', 'a', 'b', 'x', 'y'] was OK!

# %% [markdown]
# ## Assignment 3.4 (1 p)
#
# Compare sorting algorithms by taking their execution times.
#
# Use the `random` module in Python to generate a list of 10 000 random numbers by using the `random.randint()` function.
# Compare how long it takes to execute the algorithm with Python's standard `sort()` function or with your own `bubble_sort()` function.
# Use the `timeit` module to measure the execution time of each sorting method.
#
# Do the following task in the test program.
# 1. Generate a list of 10,000 random numbers
# 2. Take the time it takes to execute the Python standard function `sorted()`
# 3. Take the time it takes to execute the own implementation of `bubble_sort()` function.
#
# Please don't edit `print()` functions which shows the end times.

# %%
import random
import timeit

# No implementation needed. Use the previous implementation of bubble_sort() function.

bubblesort = '''
def bubble_sort(a):
    sorted = []
    for k in range(len(a)):
        sorted.append(a[k])
    # TODO: Sort list and return sorted list with your own implementation of bubble sort.
    for i in range(len(sorted) - 1):
        for j in range (len(sorted) - 1 - i):
            if sorted[j] > sorted[j + 1]:
                temp = sorted[j]
                sorted[j] = sorted[j + 1]
                sorted[j + 1] = temp


                
    return sorted

random_numbers = []
for i in range(10000):
    i = random.randint(0,10000)
    random_numbers.append(i)

print(bubble_sort(random_numbers))
'''

sorted ='''
random_numbers = []
for i in range(10000):
    i = random.randint(0,10000)
    random_numbers.append(i)

print(sorted(random_numbers))
'''

# Test
# TODO: Generate a list of 10,000 random numbers



# TODO: Time the execution of sorted() function
time_sorted = timeit.timeit(sorted, 'import random', number=1)
# TODO: Time the execution of bubble_sort() function
time_bubble_sort = timeit.timeit(bubblesort, 'import random', number=1)

# don't edit it these.
print(f"sorted(): {time_sorted:.6f} seconds")
print(f"bubble_sort(): {time_bubble_sort:.6f} seconds")
print(f"sorted() vs. bubble_sort(): {(time_sorted/time_bubble_sort)*100:.6f} %")
# Out:
# [0, 0, 1, 1, 3, 3, 4, 4, 5, 7, 8, 8, 9, 9, 9, 11, 12, 13, 14, 15, 16, 19, 21, 21, 21, 22, 22, 22, 22, 24, 26, 26, 26, 27, 28, 30, 32, 33, 34, 36, 36, 37, 37, 37, 37, 38, 40, 43, 44, 44, 45, 46, 46, 49, 51, 53, 54, 55, 55, 56, 58, 58, 61, 63, 63, 64, 65, 66, 66, 67, 69, 69, 69, 69, 70, 73, 74, 74, 75, 76, 78, 78, 78, 81, 81, 83, 84, 85, 86, 88, 88, 89, 89, 90, 92, 93, 95, 95, 96, 96, 99, 101, 101, 102, 102, 103, 103, 105, 106, 107, 107, 107, 109, 111, 112, 112, 113, 113, 113, 114, 115, 115, 117, 117, 117, 120, 121, 125, 125, 128, 129, 129, 130, 132, 132, 133, 133, 133, 134, 134, 135, 136, 137, 139, 142, 142, 144, 145, 145, 147, 152, 152, 156, 157, 157, 158, 158, 159, 160, 160, 161, 162, 171, 172, 172, 172, 172, 173, 175, 176, 176, 179, 180, 180, 181, 182, 183, 184, 184, 185, 185, 186, 186, 188, 190, 191, 191, 191, 191, 191, 194, 196, 196, 196, 197, 201, 201, 202, 202, 202, 203, 204, 204, 205, 206, 210, 210, 210, 211, 213, 213, 213, 213, 215, 217, 223, 226, 226, 227, 229, 229, 229, 230, 230, 231, 231, 232, 232, 233, 233, 234, 234, 235, 235, 236, 236, 238, 241, 242, 242, 242, 244, 244, 248, 249, 249, 252, 252, 252, 253, 254, 254, 257, 257, 261, 265, 265, 266, 267, 269, 271, 271, 272, 272, 276, 277, 278, 280, 280, 281, 282, 283, 283, 283, 284, 285, 286, 288, 289, 289, 290, 291, 292, 292, 292, 295, 297, 297, 298, 298, 299, 300, 300, 302, 302, 307, 307, 309, 310, 311, 311, 312, 312, 313, 313, 314, 315, 315, 316, 319, 320, 321, 324, 324, 325, 325, 326, 326, 327, 327, 328, 329, 329, 332, 340, 340, 340, 342, 343, 343, 345, 345, 345, 347, 347, 354, 355, 357, 357, 358, 359, 359, 360, 360, 365, 366, 366, 374, 376, 378, 379, 380, 381, 381, 383, 384, 385, 385, 387, 387, 388, 388, 389, 390, 391, 391, 393, 393, 394, 395, 396, 396, 397, 399, 400, 400, 402, 402, 402, 403, 406, 406, 406, 406, 407, 409, 409, 412, 413, 414, 416, 417, 419, 422, 423, 426, 426, 428, 431, 431, 433, 433, 437, 438, 438, 438, 440, 440, 441, 443, 445, 445, 448, 452, 452, 453, 456, 462, 462, 463, 463, 463, 463, 465, 466, 468, 468, 469, 472, 473, 475, 475, 475, 476, 476, 476, 477, 478, 478, 479, 480, 480, 480, 480, 481, 484, 484, 485, 486, 487, 487, 487, 489, 490, 490, 493, 493, 494, 495, 496, 497, 499, 500, 501, 501, 501, 501, 502, 504, 506, 506, 506, 508, 509, 509, 511, 512, 514, 514, 515, 516, 516, 517, 518, 520, 521, 523, 524, 525, 526, 526, 527, 528, 529, 530, 530, 530, 530, 532, 534, 534, 536, 536, 537, 537, 538, 540, 541, 542, 545, 546, 547, 547, 547, 548, 548, 549, 550, 551, 553, 554, 555, 556, 560, 563, 565, 566, 566, 567, 568, 569, 569, 570, 574, 574, 575, 577, 577, 579, 580, 581, 582, 586, 586, 589, 589, 590, 591, 592, 593, 596, 598, 599, 601, 604, 605, 605, 605, 605, 606, 606, 606, 607, 608, 609, 611, 613, 613, 614, 614, 617, 618, 618, 619, 621, 623, 626, 629, 630, 633, 634, 637, 637, 640, 640, 641, 642, 647, 648, 648, 648, 649, 650, 652, 654, 655, 656, 656, 662, 663, 664, 664, 665, 668, 668, 670, 670, 671, 672, 673, 673, 674, 674, 674, 675, 676, 676, 678, 679, 681, 682, 683, 683, 687, 688, 689, 692, 692, 694, 696, 696, 697, 697, 698, 698, 699, 701, 702, 702, 703, 704, 704, 708, 709, 710, 714, 714, 715, 717, 718, 719, 721, 722, 724, 725, 726, 726, 726, 727, 729, 732, 732, 733, 735, 737, 737, 739, 748, 749, 750, 752, 752, 752, 753, 754, 756, 758, 758, 758, 760, 760, 762, 763, 763, 763, 763, 763, 764, 764, 764, 765, 765, 765, 766, 767, 768, 769, 772, 773, 776, 777, 780, 780, 784, 784, 786, 787, 787, 788, 789, 790, 790, 791, 791, 792, 793, 793, 795, 799, 799, 800, 801, 801, 803, 804, 805, 805, 806, 807, 808, 808, 809, 809, 810, 810, 811, 812, 813, 813, 814, 814, 815, 816, 819, 821, 821, 822, 823, 823, 823, 823, 824, 824, 826, 826, 829, 830, 831, 834, 836, 838, 838, 840, 840, 840, 841, 841, 842, 844, 844, 845, 848, 848, 850, 850, 851, 853, 856, 857, 857, 858, 858, 859, 859, 860, 861, 861, 861, 861, 861, 862, 863, 864, 866, 868, 868, 869, 870, 872, 872, 873, 875, 875, 875, 876, 876, 877, 878, 878, 881, 881, 881, 881, 882, 883, 884, 884, 884, 886, 886, 889, 889, 891,  ...
# [1, 3, 4, 5, 6, 6, 7, 8, 8, 9, 10, 11, 13, 13, 14, 14, 14, 15, 17, 17, 18, 18, 19, 19, 22, 24, 24, 27, 28, 29, 29, 29, 29, 33, 34, 34, 35, 36, 38, 38, 41, 42, 43, 43, 45, 47, 47, 47, 48, 48, 49, 49, 50, 51, 51, 51, 52, 52, 53, 54, 56, 56, 56, 58, 58, 58, 60, 61, 61, 61, 62, 62, 63, 64, 66, 66, 70, 71, 72, 72, 73, 74, 75, 75, 77, 77, 77, 78, 78, 80, 80, 81, 82, 84, 85, 86, 87, 88, 88, 89, 92, 93, 95, 96, 98, 98, 98, 98, 99, 103, 106, 107, 107, 108, 108, 111, 113, 114, 115, 116, 116, 116, 117, 119, 120, 122, 122, 122, 122, 123, 123, 126, 127, 127, 130, 131, 131, 134, 134, 135, 136, 137, 137, 138, 139, 139, 140, 140, 141, 142, 144, 145, 147, 150, 151, 154, 156, 157, 157, 160, 160, 162, 164, 164, 164, 167, 167, 167, 171, 171, 171, 172, 172, 174, 175, 176, 176, 176, 177, 178, 178, 181, 181, 183, 183, 184, 185, 186, 186, 187, 188, 188, 189, 189, 192, 195, 198, 199, 199, 199, 199, 202, 202, 203, 204, 204, 204, 204, 205, 206, 207, 210, 212, 212, 213, 214, 214, 216, 216, 216, 217, 218, 218, 219, 219, 221, 222, 222, 222, 223, 223, 223, 223, 223, 226, 226, 227, 227, 227, 229, 230, 230, 230, 231, 233, 234, 237, 237, 239, 240, 240, 240, 244, 244, 244, 245, 245, 245, 246, 247, 247, 248, 249, 250, 250, 251, 251, 252, 253, 256, 257, 258, 258, 258, 259, 260, 261, 261, 262, 263, 264, 264, 265, 265, 266, 266, 267, 267, 269, 270, 270, 270, 274, 274, 275, 275, 277, 278, 283, 285, 286, 287, 288, 289, 290, 293, 294, 294, 295, 299, 299, 301, 304, 305, 306, 307, 307, 307, 309, 311, 312, 313, 316, 317, 317, 320, 320, 322, 323, 324, 324, 324, 324, 325, 327, 328, 328, 331, 332, 334, 335, 336, 336, 337, 338, 338, 339, 339, 340, 341, 341, 342, 345, 345, 345, 345, 349, 352, 353, 353, 353, 355, 356, 356, 362, 362, 363, 363, 363, 364, 365, 365, 366, 367, 368, 369, 369, 371, 372, 373, 376, 379, 384, 384, 385, 387, 387, 387, 388, 388, 389, 390, 391, 394, 394, 395, 396, 399, 402, 405, 406, 406, 408, 409, 409, 411, 411, 411, 417, 418, 419, 420, 420, 421, 422, 424, 425, 425, 427, 427, 428, 429, 430, 431, 431, 432, 432, 433, 433, 434, 435, 436, 437, 438, 438, 439, 439, 439, 440, 442, 443, 443, 447, 447, 448, 448, 450, 450, 451, 451, 452, 452, 454, 454, 456, 456, 459, 460, 461, 461, 461, 462, 463, 464, 465, 465, 465, 466, 466, 468, 468, 469, 470, 471, 472, 473, 473, 474, 474, 476, 477, 477, 479, 480, 481, 483, 484, 485, 486, 487, 488, 489, 489, 489, 491, 492, 494, 495, 495, 496, 496, 500, 501, 503, 504, 504, 506, 508, 508, 509, 510, 511, 512, 515, 515, 516, 516, 517, 522, 522, 522, 522, 523, 523, 523, 524, 526, 527, 529, 529, 530, 531, 535, 537, 540, 541, 542, 543, 544, 544, 545, 545, 545, 546, 546, 547, 547, 549, 550, 550, 551, 552, 553, 553, 554, 554, 554, 555, 556, 556, 556, 557, 557, 559, 559, 559, 559, 560, 561, 563, 564, 565, 567, 567, 569, 571, 571, 574, 575, 577, 578, 579, 579, 580, 580, 581, 582, 584, 588, 588, 591, 591, 592, 592, 593, 594, 594, 594, 595, 595, 599, 599, 599, 600, 601, 601, 602, 603, 604, 605, 606, 607, 607, 609, 610, 610, 612, 613, 614, 614, 615, 616, 617, 618, 619, 619, 623, 623, 624, 624, 625, 626, 626, 626, 628, 628, 628, 629, 630, 630, 633, 633, 634, 635, 637, 637, 637, 638, 638, 638, 639, 639, 642, 642, 645, 646, 647, 647, 647, 647, 648, 648, 650, 650, 651, 652, 654, 654, 655, 657, 657, 657, 658, 658, 660, 660, 661, 661, 662, 664, 666, 666, 667, 668, 668, 669, 670, 672, 672, 674, 674, 674, 675, 675, 678, 679, 679, 683, 683, 688, 688, 688, 688, 690, 690, 690, 690, 691, 691, 691, 692, 692, 692, 693, 693, 694, 694, 695, 699, 699, 703, 705, 706, 706, 707, 707, 708, 708, 709, 710, 711, 711, 711, 716, 716, 717, 717, 720, 722, 722, 723, 723, 724, 725, 727, 727, 727, 729, 731, 733, 733, 734, 735, 735, 736, 736, 737, 737, 738, 738, 738, 739, 741, 744, 744, 744, 744, 745, 745, 747, 747, 749, 751, 751, 751, 752, 753, 753, 753, 756, 757, 759, 759, 759, 760, 761, 762, 762, 762, 762, 762, 763, 763, 763, 765, 766, 768, 769, 769, 770, 770, 772, 775, 779, 781, 781, 781, 782, 783, 786, 786, 787, 787, 788, 790, 790, 791, 792, 792, 793, 793, 794, 794, 797 ...
# sorted(): 0.039169 seconds
# bubble_sort(): 13.669572 seconds
# sorted() vs. bubble_sort(): 0.286539 %
